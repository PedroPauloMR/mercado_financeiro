# %%
import yfinance as yf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tickers = "TAEE4.SA ITSA4.SA TAEE3.SA EGIE3.SA ENBR3.SA WEGE3.SA HYPE3.SA SQIA3.SA ITSA3.SA"
carteira = yf.download(tickers, period = '19mo')['Adj Close']
ibov = yf.download('^BVSP', period = '19mo')['Adj Close']
bova = yf.download('BOVA11.SA', period = '19mo')['Adj Close']
small = yf.download('SMAL11.SA', period = '19mo')['Adj Close']
# Out:
# [*********************100%***********************]  9 of 9 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
carteira.dropna(inplace = True)
carteira
# Out:
#              EGIE3.SA   ENBR3.SA   HYPE3.SA   ITSA3.SA   ITSA4.SA   SQIA3.SA  \
# Date
# 2019-11-22  40.427528  17.547102  32.727924  13.002766  12.951622  17.724346
# 2019-11-25  40.418610  17.583961  32.794235  12.803306  12.639874  17.724346
# 2019-11-26  39.964077  17.722202  32.557415  12.442386  12.337578  17.634426
# 2019-11-27  40.516655  17.768282  31.875393  12.660837  12.488728  17.634426
# 2019-11-28  41.318787  18.026327  31.809080  12.641843  12.517066  17.414619
# ...               ...        ...        ...        ...        ...        ...
# 2021-06-16  41.090000  18.709999  35.990002  12.150000  11.930000  22.219999
# 2021-06-17  41.110001  18.830000  36.070000  12.070000  11.820000  22.260000
# 2021-06-18  41.529999  19.170000  36.299999  12.010000  11.710000  22.889999
# 2021-06-21  41.000000  18.799999  36.520000  11.960000  11.740000  22.350000
# 2021-06-22  40.560001  18.620001  36.400002  11.870000  11.660000  22.309999
#
# ...

# %%
ibov.dropna(inplace = True)
ibov
# Out:
# Date
# 2019-11-22    108692.000000
# 2019-11-25    108424.000000
# 2019-11-26    107059.000000
# 2019-11-27    107708.000000
# 2019-11-28    108290.000000
#                   ...
# 2021-06-16    129259.000000
# 2021-06-17    128057.000000
# 2021-06-18    128405.000000
# 2021-06-21    129265.000000
# 2021-06-22    128402.351562
# Name: Adj Close, Length: 387, dtype: float64

# %%
bova.dropna(inplace = True)
bova
# Out:
# Date
# 2019-11-22    104.599998
# 2019-11-25    104.250000
# 2019-11-26    103.440002
# 2019-11-27    103.680000
# 2019-11-28    104.379997
#                  ...
# 2021-06-16    124.220001
# 2021-06-17    123.089996
# 2021-06-18    123.269997
# 2021-06-21    124.230003
# 2021-06-22    123.480003
# Name: Adj Close, Length: 387, dtype: float64

# %%
small.dropna(inplace = True)
small
# Out:
# Date
# 2019-11-22    119.400002
# 2019-11-25    119.690002
# 2019-11-26    119.480003
# 2019-11-27    119.750000
# 2019-11-28    121.199997
#                  ...
# 2021-06-16    152.970001
# 2021-06-17    151.800003
# 2021-06-18    152.600006
# 2021-06-21    154.500000
# 2021-06-22    153.449997
# Name: Adj Close, Length: 387, dtype: float64

# %%
sns.set()
carteira.plot(figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_normalizada = (carteira / carteira.iloc[0])*10000
carteira_normalizada.dropna(inplace = True)

carteira_normalizada.plot(figsize = (17,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_normalizada['saldo'] = carteira_normalizada.sum(axis = 1)
carteira_normalizada
# Out:
#                 EGIE3.SA      ENBR3.SA      HYPE3.SA      ITSA3.SA  \
# Date
# 2019-11-22  10000.000000  10000.000000  10000.000000  10000.000000
# 2019-11-25   9997.793889  10021.006040  10020.261255   9846.601842
# 2019-11-26   9885.362424  10099.788744   9947.900962   9569.030161
# 2019-11-27  10022.046014  10126.049283   9739.509471   9737.034035
# 2019-11-28  10220.458256  10273.107867   9719.247633   9722.426118
# ...                  ...           ...           ...           ...
# 2021-06-16  10163.866503  10662.728872  10996.726006   9344.165649
# 2021-06-17  10168.813741  10731.116712  11021.169358   9282.640336
# 2021-06-18  10272.702894  10924.880988  11091.445596   9236.496717
# 2021-06-21  10141.604407  10714.019480  11158.666853   9198.043213
# 2021-06-22  10032.768017  10611.439351  11122.001243   9128.827051
#
#                 ITSA4.SA      SQIA3.SA      TAEE3.SA      TAEE4.SA  \
# Date
# 2019-11-22  10000.000000  10000.000000  10000.000000  10000.000000
# ...

# %%
ibov_normalizado = (ibov / ibov.iloc[0]) * 90000
ibov_normalizado
# Out:
# Date
# 2019-11-22     90000.000000
# 2019-11-25     89778.088544
# 2019-11-26     88647.830567
# 2019-11-27     89185.220623
# 2019-11-28     89667.132816
#                   ...
# 2021-06-16    107030.048210
# 2021-06-17    106034.758768
# 2021-06-18    106322.912450
# 2021-06-21    107035.016377
# 2021-06-22    106320.719470
# Name: Adj Close, Length: 387, dtype: float64

# %%
bova_normalizado = (bova / bova.iloc[0]) * 90000
bova_normalizado
# Out:
# Date
# 2019-11-22     90000.000000
# 2019-11-25     89698.854081
# 2019-11-26     89001.915445
# 2019-11-27     89208.414566
# 2019-11-28     89810.706404
#                   ...
# 2021-06-16    106881.455764
# 2021-06-17    105909.176214
# 2021-06-18    106064.052196
# 2021-06-21    106890.061809
# 2021-06-22    106244.746312
# Name: Adj Close, Length: 387, dtype: float64

# %%
small_normalizado = (small / small.iloc[0]) * 90000
small_normalizado
# Out:
# Date
# 2019-11-22     90000.000000
# 2019-11-25     90218.593652
# 2019-11-26     90060.302887
# 2019-11-27     90263.817942
# 2019-11-28     91356.780452
#                   ...
# 2021-06-16    115304.019547
# 2021-06-17    114422.111391
# 2021-06-18    115025.128759
# 2021-06-21    116457.284944
# 2021-06-22    115665.825367
# Name: Adj Close, Length: 387, dtype: float64

# %%
carteira_normalizada['saldo'].plot(figsize=(18,8), label = 'Minha Carteira')
ibov_normalizado.plot(label = 'IBOV')
bova_normalizado.plot(label = 'BOVA11')
small_normalizado.plot(label = 'SMAL11')
plt.legend();

# %%
carteira_normalizada.describe()
# Out:
#            EGIE3.SA      ENBR3.SA      HYPE3.SA      ITSA3.SA      SQIA3.SA  \
# count    387.000000    387.000000    387.000000    387.000000    387.000000
# mean   10283.742003  10199.175659   9873.837414   8696.411248  12368.271168
# std      759.224880    908.849304    780.756244    768.758484   1595.331071
# min     8559.745322   7372.824326   7823.453053   6924.197844   6736.189264
# 25%     9887.500597   9610.057246   9348.391367   8176.397430  11727.734744
# 50%    10213.699328  10221.507467   9929.379916   8595.330425  12542.277982
# 75%    10665.925698  10738.340289  10434.506189   9195.552085  13255.355139
# max    12329.131594  12403.880112  12196.411906  10421.894257  16623.449771
#
#            TAEE3.SA      WEGE3.SA         saldo
# count    387.000000    387.000000    387.000000
# mean   11983.871728  20720.029164  84125.338384
# std     2182.492142   6340.416893   9557.270527
# min     8850.103728   9149.851832  58569.328626
# ...
